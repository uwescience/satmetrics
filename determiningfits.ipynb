# %%
import line_detection
import image_rotation
from pixelplot import pixelplot
from astropy.io import fits
import astropy.visualization as aviz
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as optim
import gaussian
# %matplotlib inline

# %%
xlim = (-20, 20)
step = 0.5
x = np.arange(xlim[0], xlim[1], step)

fig, axes = plt.subplots(2, 3, figsize=(15, 15))
axes = axes.ravel()

noise = [1, 2, 3, 4, 5, 6]

for i, ax in zip(noise, axes):
    y = gaussian.generate_data(x, a=0.5, mu=0, width=1, noise_level=i)
    ax = gaussian.plot_profile(x, y, ax)
    ax.set_title(f"Parameter = {i}")

# %%
    if r2 <= 0.2:
        return True
    elif nr2 <= 3:
        return True
    else a > mu:
        return True
