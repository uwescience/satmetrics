# %%
import line_detection
import image_rotation
from pixelplot import pixelplot
from astropy.io import fits
import astropy.visualization as aviz
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as optim
import gaussian
# %matplotlib inline

# %%
xlim = (-20, 20)
step = 0.5
x = np.arange(xlim[0], xlim[1], step)

fig, axes = plt.subplots(2, 3, figsize=(15, 15))
axes = axes.ravel()

noise = [20, 15, 8, 7, 4, 3]

for i, ax in zip(noise, axes):
    y = gaussian.generate_data(x, a=0.5, mu=10, width=1, noise_level=i)
    ax = gaussian.plot_profile(x, y, ax)
    validate_streak(a, mu, r2, nr2, xmax=xlim[1], xmin=xlim[0], sigma=10)
    if validate_streak = True
    ax.set_title(f"Noise level = {i}")

# %%
"""guessed different noise parameters to see which plots i would believe to contain a streak
when there are plots with noise that are 'borderline' believeable, i pick values between the parameter numbers 
cross off which don't fit, and accept the ones that do and look at the r2 values to see the pattern if r2 is 
increasing and decreasing
